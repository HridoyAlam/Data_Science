# %%
import pandas as pd
import numpy as np
#inline backend
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#check matplot version
print('Matplotlib version: ',mpl.__version__)
# Out:
# Matplotlib version:  3.1.1

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
df_canada = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                         sheet_name='Canada by Citizenship',
                         skiprows = range(20),
                         skipfooter = 2)

# %%
df_canada.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
# 1  901   Developed regions     1  ...  1450  1223   856   702   560   716
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
#
# [2 rows x 43 columns]

# %%
df_canada.columns.values
df_canada.columns.tolist()
df_canada.index.tolist()

print(type(df_canada.columns.tolist()))
# Out:
# <class 'list'>

# %%
df_canada.drop(['AREA','REG','DEV','Type','Coverage'],axis=1,inplace = True)

# %%
df_canada.rename(columns ={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace = True)

# %%
df_canada.columns.values
# Out:
# array(['Country', 'Continent', 'Region', 'DevName', 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], dtype=object)

# %%
df_canada['Total'] = df_canada.sum(axis=1)
df_canada.columns.values
# Out:
# array(['Country', 'Continent', 'Region', 'DevName', 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 'Total'],
#       dtype=object)

# %%
df_canada.set_index('Country', inplace=True)

# %%
df_canada.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
print(df_canada.loc['Japan'])
# Out:
# Continent                 Asia
# Region            Eastern Asia
# DevName      Developed regions
# 1980                       701
# 1981                       756
# 1982                       598
# 1983                       309
# 1984                       246
# 1985                       198
# 1986                       248
# 1987                       422
# 1988                       324
# 1989                       494
# 1990                       379
# 1991                       506
# 1992                       605
# 1993                       907
# 1994                       956
# 1995                       826
# 1996                       994
# 1997                       924
# 1998                       897
# 1999                      1083
# 2000                      1010
# 2001                      1092
# 2002                       806
# 2003                       817
# 2004                       973
# 2005                      1067
# 2006                      1212
# ...

# %%
print(df_canada.loc['Haiti'])
# Out:
# Continent    Latin America and the Caribbean
# Region                             Caribbean
# DevName                   Developing regions
# 1980                                    1666
# 1981                                    3692
# 1982                                    3498
# 1983                                    2860
# 1984                                    1418
# 1985                                    1321
# 1986                                    1753
# 1987                                    2132
# 1988                                    1829
# 1989                                    2377
# 1990                                    2379
# 1991                                    2829
# 1992                                    2399
# 1993                                    3655
# 1994                                    2100
# 1995                                    2014
# 1996                                    1955
# 1997                                    1645
# ...

# %%
print(df_canada.loc['Haiti', [1980,1982,1983,1984,1985,1986,1987]])
# Out:
# 1980    1666
# 1982    3498
# 1983    2860
# 1984    1418
# 1985    1321
# 1986    1753
# 1987    2132
# Name: Haiti, dtype: object

# %%
df_canada.columns = list(map(str,df_canada.columns))

# %%
years = list(map(str, range(1980, 2014)))

# %%
haiti = df_canada.loc['Haiti',years]

# %%
#get the data series of haiti
#haiti = df_canada.loc['Haiti',[1980,1982,1983,1984,1985,1986,1987,1988,1889,1990,1991,1992,1993]]

haiti.head()
# Out:
# 1980    1666
# 1981    3692
# 1982    3498
# 1983    2860
# 1984    1418
# Name: Haiti, dtype: object

# %%
haiti.plot()

# %%
haiti.index = haiti.index.map(int) # lets change the index values of haiti into the type of integers
haiti.plot(kind='line')

plt.title('Immigration from haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.show()

# %%
haiti.plot(kind='line')
plt.title('Immigration from haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

#annote the 2010 EarthQuake
#syntex: plt.text(x,y,label)
plt.text(2000,6000,'2010 Eartquake')
# Out:
# Text(2000, 6000, '2010 Eartquake')

# %%
china = df_canada.loc['China',years]
china.head()
# Out:
# 1980    5123
# 1981    6682
# 1982    3308
# 1983    1863
# 1984    1527
# Name: China, dtype: object

# %%
india = df_canada.loc['India',years]
india.head()
# Out:
# 1980    8880
# 1981    8670
# 1982    8147
# 1983    7338
# 1984    5704
# Name: India, dtype: object

# %%
#get india and china data set together
df_CI = df_canada.loc[['India', 'China'],years]
df_CI.head()
# Out:
#          1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# Country                                                                 ...
# India    8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
# China    5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# Country
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# China    36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
#
# [2 rows x 34 columns]

# %%
df_CI.plot(kind='line')

# %%
#it doesn't look good, so need to change the row and columns using pandas transpose() method
df_CI = df_CI.transpose()
df_CI.head()
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527

# %%
df_CI.plot(kind='line')

# %%
df_CI.index = df_CI.index.map(int)
df_CI.plot(kind = 'line')
plt.title('Immigration from China and india')
plt.xlabel('Years')
plt.ylabel('Numbers')
plt.show()

# %%
#Q: compare the trend of top 5 countries that contributed the most to immigration to canda

#inplace = True parameter saves the changes to the orginal df_canada dataframe
df_canada.sort_values(by='Total', ascending = False, axis =0, inplace = True)

df_top5 = df_canada.head(5)

df_top5 = df_top5[years].transpose
