# %%
# %matplotlib notebook #it will show the figure
import matplotlib.pyplot as plt
# Out:
# UsageError: unrecognized arguments: #it will show the figure

# %%
#plt.plot(5, 5, 'o')

# %%
import pandas as pd
table = {'India':[8880,8670,8147,7338,874],
        'China':[5123, 6682, 3308, 1863, 1527]}
df = pd.DataFrame(table, index =[1980,1981,1982,1983,1984])
print(df)
# Out:
#       India  China
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984    874   1527

# %%
df['India'].plot(kind='hist')
#df['China'].plot(kind='line')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
