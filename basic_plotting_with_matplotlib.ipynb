# %%
# %matplotlib notebook #it will show the figure
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#india_china_df("India").plot(kind="hist")
#india_china_df("India").plot(kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-147ed421d316> in <module>
# ----> 1 india_china_df("India").plot(kind="hist")
#
# NameError: name 'india_china_df' is not defined
